# %% [markdown]
# # Skrypt do pobierania danych aktualnych oraz historycznych + przetwarzanie i korekta.
#
# Korekta i przetwarzanie danych wynikały z mojej analizy w notebooku data_analysis. W dokumentacji jest 60 kolumn, które raz są opisane a raz nie. Analizując trendy, dane i średnie mogłem wywnioskować która kolumna została źle wczytana, lub trzeba zastosować korekte wynikającą z danych w innych kolumnach.
#
# Dane pobierane są w loopie jako zipy i concatowane do jednego dataframe. Można wybrać dowolny zakres lat i dowolną stację. ID stacji dla aktualnych danych z API ma inny format niż z danych historycznych.

# %%
import pandas as pd
import requests
import warnings
import os
import zipfile
import numpy as np

warnings.filterwarnings('ignore')

# %%
STACJA_ID = "12600"  # Bielsko-Biała
BASE_URL = "https://danepubliczne.imgw.pl/api/data/synop"

# %%
def pobierz_aktualne_dane():
    """Pobiera aktualne dane dla stacji Bielsko-Biała"""
    url = f"{BASE_URL}/id/{STACJA_ID}"
    response = requests.get(url)
    if response.status_code == 200:
        return response.json()
    return None

def pobierz_wszystkie_stacje():
    """Pobiera dane ze wszystkich stacji"""
    response = requests.get(BASE_URL)
    if response.status_code == 200:
        return response.json()
    return None

# %%
aktualne_dane = pobierz_aktualne_dane()
print("Aktualne dane dla Bielska-Białej:")
print(pd.DataFrame([aktualne_dane]))
# Out:
# Aktualne dane dla Bielska-Białej:
#   id_stacji         stacja data_pomiaru godzina_pomiaru temperatura  \
# 0     12600  Bielsko Biała   2025-01-04              20        -2.6
#
#   predkosc_wiatru kierunek_wiatru wilgotnosc_wzgledna suma_opadu cisnienie
# 0               4             180                65.7        0.1    1021.7

# %%
def pobierz_dane_historyczne(rok, stacja_id='600'):
    """
    Pobiera dane historyczne dla wybranej stacji za dany rok
    """
    os.makedirs('dane', exist_ok=True)
    filename = f"{rok}_{stacja_id}_s.zip"
    url = f"https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/terminowe/synop/{rok}/{filename}"
    
    try:
        print(f"Pobieranie danych z: {url}")
        response = requests.get(url)
        
        if response.status_code == 200:
            zip_path = os.path.join('dane', filename)
            
            with open(zip_path, 'wb') as f:
                f.write(response.content)
            print(f"Zapisano plik ZIP: {zip_path}")
            
            with zipfile.ZipFile(zip_path, 'r') as zip_ref:
                print("Pliki w archiwum:")
                for name in zip_ref.namelist():
                    print(f"- {name}")
                
                csv_files = [f for f in zip_ref.namelist() if f.endswith('.csv')]
                if csv_files:
                    with zip_ref.open(csv_files[0]) as f:
                        df = pd.read_csv(
                            f,
                            encoding='cp1250',
                            sep=',',
                            quotechar='"',
                            na_values=['', '""'],
                            header=None
                        )
                        
                        print("\nPierwszy wiersz surowych danych:")
                        for i, value in enumerate(df.iloc[0]):
                            print(f"Kolumna {i}: {value}")
                            
                        print("\nSprawdzanie konkretnych kolumn:")
                        print("Wilgotność względna (kolumna 38):", df[37].head())
                        print("Suma opadów (kolumna 47):", df[46].head())
                        
                        df_clean = pd.DataFrame({
                            'data_pomiaru': pd.to_datetime(df[[2, 3, 4]].astype(str).agg('-'.join, axis=1)),
                            'godzina_pomiaru': df[5].astype(str).str.zfill(2),
                            'temperatura': pd.to_numeric(df[29], errors='coerce'),  
                            'predkosc_wiatru': pd.to_numeric(df[25], errors='coerce'),
                            'kierunek_wiatru': pd.to_numeric(df[23], errors='coerce'),
                            'wilgotnosc_wzgledna': pd.to_numeric(df[37], errors='coerce'),
                            'suma_opadu': pd.to_numeric(df[46], errors='coerce'),  # Odczytujemy wartość opadu
                            'status_opadu': df[47],  # Odczytujemy status opadu
                            'cisnienie': pd.to_numeric(df[41], errors='coerce')
                        })
                        # Przetwarzanie opadów
                        df_clean['suma_opadu'] = df_clean.apply(
                            lambda row: 0 if row['status_opadu'] == '9'  # Brak zjawiska
                            else np.nan if row['status_opadu'] == '8'  # Brak pomiaru
                            else np.nan if row['suma_opadu'] < 0  # Ujemne wartości traktujemy jako błąd
                            else row['suma_opadu'],
                            axis=1
                        )

                        df_clean['suma_opadu'] = df_clean['suma_opadu'].fillna(0)

                        df_clean = df_clean.drop('status_opadu', axis=1)

                        print("\nPo przetworzeniu - pierwsze wiersze:")
                        print(df_clean.head())
                        print("\nBrakujące wartości po przetworzeniu:")
                        print(df_clean.isnull().sum())
                        
                        return df_clean
                else:
                    print("Nie znaleziono pliku CSV w archiwum")
                    return None
            
    except Exception as e:
        print(f"Błąd podczas pobierania danych: {e}")
        return None

def pobierz_dane_wieloletnie(lata, stacja_id='600'):
    """
    Pobiera dane z wielu lat i łączy je w jeden DataFrame
    
    Args:
        lata (list): Lista lat do pobrania
        stacja_id (str): ID stacji (np. '600' dla Bielska-Białej)
    """
    wszystkie_dane = []
    
    for rok in lata:
        print(f"\nPobieranie danych za rok {rok}")
        df = pobierz_dane_historyczne(rok, stacja_id)
        if df is not None:
            wszystkie_dane.append(df)
    
    if wszystkie_dane:
        df_final = pd.concat(wszystkie_dane, ignore_index=True)
        print(f"\nŁączna liczba rekordów: {len(df_final)}")
        
        output_path = os.path.join('dane', f'dane_stacja_{stacja_id}.csv')
        df_final.to_csv(output_path, index=False)
        print(f"Zapisano połączone dane do: {output_path}")
        
        return df_final
    return None

# %%
lata_do_pobrania = [2020, 2021, 2022, 2023] # niestety w roku 2024 format plików się zmienił
nr_stacji = 600 # Bielsko
dane = pobierz_dane_wieloletnie(lata_do_pobrania, nr_stacji)

if dane is not None:
    print("\nPrzykładowe dane:")
    print(dane.head())
    print("\nKolumny w danych:")
    print(dane.columns.tolist())
# Out:
# Pobieranie danych za rok 2020
# Pobieranie danych z: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/terminowe/synop/2020/2020_600_s.zip
# Zapisano plik ZIP: dane/2020_600_s.zip
# Pliki w archiwum:
# - s_t_600_2020.csv
#
# Pierwszy wiersz surowych danych:
# Kolumna 0: 349190600
# Kolumna 1: BIELSKO-BIAŁA
# Kolumna 2: 2020
# Kolumna 3: 1
# Kolumna 4: 1
# Kolumna 5: 0
# Kolumna 6: 4
# Kolumna 7: nan
# Kolumna 8: 500
# Kolumna 9: nan
# Kolumna 10: 800
# Kolumna 11: nan
# Kolumna 12: 500/800
# Kolumna 13: nan
# Kolumna 14: nan
# Kolumna 15: 7
# Kolumna 16: nan
# Kolumna 17: 10000
# Kolumna 18: nan
# Kolumna 19: 10475
# Kolumna 20: nan
# Kolumna 21: 7
# Kolumna 22: nan
# Kolumna 23: 251
# Kolumna 24: nan
# Kolumna 25: 4
# Kolumna 26: nan
# Kolumna 27: 0
# Kolumna 28: 9.0
# Kolumna 29: 2.8
# Kolumna 30: nan
# Kolumna 31: 0.0
# Kolumna 32: 8
# Kolumna 33: U
# Kolumna 34: nan
# Kolumna 35: 5.9
# Kolumna 36: nan
# Kolumna 37: 79
# Kolumna 38: nan
# Kolumna 39: -0.5
# Kolumna 40: nan
# Kolumna 41: 982.8
# Kolumna 42: nan
# Kolumna 43: 1032.7
# Kolumna 44: nan
# Kolumna 45: 2
# Kolumna 46: 0.9
# Kolumna 47: nan
# Kolumna 48: 0.0
# Kolumna 49: 9.0
# Kolumna 50: 0
# Kolumna 51: 9.0
# Kolumna 52: 2
# Kolumna 53: 2
# Kolumna 54: 7
# Kolumna 55: nan
# Kolumna 56: 5
# Kolumna 57: nan
# Kolumna 58: Sc pe 3 / Sc pe
# Kolumna 59: /
# Kolumna 60: nan
# Kolumna 61: /
# Kolumna 62: /
# Kolumna 63: nan
# Kolumna 64: /
# Kolumna 65: 1
# Kolumna 66: nan
# Kolumna 67: 1.6
# Kolumna 68: nan
# Kolumna 69: 0.0
# Kolumna 70: 8.0
# Kolumna 71: 0
# Kolumna 72: nan
# Kolumna 73: 0
# Kolumna 74: 9.0
# Kolumna 75: nan
# Kolumna 76: nan
# Kolumna 77: 1.9
# Kolumna 78: nan
# Kolumna 79: 0.0
# Kolumna 80: 8.0
# Kolumna 81: 0.0
# Kolumna 82: 8.0
# Kolumna 83: 0.0
# Kolumna 84: 8.0
# Kolumna 85: 0.0
# Kolumna 86: 8.0
# Kolumna 87: 0.0
# Kolumna 88: 8.0
# Kolumna 89: 0.0
# Kolumna 90: 8.0
# Kolumna 91: 0.0
# Kolumna 92: 8.0
# Kolumna 93: 0.0
# Kolumna 94: 8.0
# Kolumna 95: 0
# Kolumna 96: 8.0
# Kolumna 97: 0
# Kolumna 98: 8.0
# Kolumna 99: 0
# Kolumna 100: 8.0
# Kolumna 101: nan
# Kolumna 102: nan
# Kolumna 103: 0
# Kolumna 104: 8.0
# Kolumna 105: 0
# Kolumna 106: 8.0
#
# Sprawdzanie konkretnych kolumn:
# Wilgotność względna (kolumna 38): 0    79
# 1    80
# 2    81
# 3    81
# 4    81
# Name: 37, dtype: int64
# Suma opadów (kolumna 47): 0    0.9
# 1    0.7
# 2    0.3
# 3    0.2
# 4    0.6
# Name: 46, dtype: float64
#
# Po przetworzeniu - pierwsze wiersze:
#   data_pomiaru godzina_pomiaru  temperatura  predkosc_wiatru  kierunek_wiatru  \
# 0   2020-01-01              00          2.8                4              251
# 1   2020-01-01              01          2.7                5              245
# 2   2020-01-01              02          2.7                4              249
# 3   2020-01-01              03          2.6                4              250
# 4   2020-01-01              04          2.4                3              275
#
#    wilgotnosc_wzgledna  suma_opadu  cisnienie
# 0                   79         0.9      982.8
# 1                   80         0.7      982.9
# 2                   81         0.3      983.0
# 3                   81         0.2      983.0
# 4                   81         0.6      983.5
#
# Brakujące wartości po przetworzeniu:
# data_pomiaru           0
# godzina_pomiaru        0
# temperatura            0
# predkosc_wiatru        0
# kierunek_wiatru        0
# wilgotnosc_wzgledna    0
# suma_opadu             0
# cisnienie              0
# dtype: int64
#
# Pobieranie danych za rok 2021
# Pobieranie danych z: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/terminowe/synop/2021/2021_600_s.zip
# Zapisano plik ZIP: dane/2021_600_s.zip
# Pliki w archiwum:
# - s_t_600_2021.csv
#
# Pierwszy wiersz surowych danych:
# Kolumna 0: 349190600
# Kolumna 1: BIELSKO-BIAŁA
# Kolumna 2: 2021
# Kolumna 3: 1
# Kolumna 4: 1
# Kolumna 5: 0
# Kolumna 6: 2
# Kolumna 7: nan
# Kolumna 8: 150
# Kolumna 9: nan
# Kolumna 10: 0
# Kolumna 11: 8.0
# Kolumna 12: 150
# Kolumna 13: nan
# Kolumna 14: nan
# Kolumna 15: 5
# Kolumna 16: nan
# Kolumna 17: 2000
# Kolumna 18: nan
# Kolumna 19: 1886
# Kolumna 20: nan
# Kolumna 21: 7
# Kolumna 22: nan
# Kolumna 23: 94
# Kolumna 24: nan
# Kolumna 25: 2
# Kolumna 26: nan
# Kolumna 27: 0
# Kolumna 28: 9.0
# Kolumna 29: -0.6
# Kolumna 30: nan
# Kolumna 31: 0.0
# Kolumna 32: 8.0
# Kolumna 33: U
# Kolumna 34: nan
# Kolumna 35: 5.9
# Kolumna 36: nan
# Kolumna 37: 100
# Kolumna 38: nan
# Kolumna 39: -0.6
# Kolumna 40: nan
# Kolumna 41: 960.3
# Kolumna 42: nan
# Kolumna 43: 1009.7
# Kolumna 44: nan
# Kolumna 45: 7
# Kolumna 46: -0.7
# Kolumna 47: nan
# Kolumna 48: 0.0
# Kolumna 49: 9.0
# Kolumna 50: 0
# Kolumna 51: 9.0
# Kolumna 52: 10
# Kolumna 53: 4
# Kolumna 54: 7.0
# Kolumna 55: nan
# Kolumna 56: 6
# Kolumna 57: nan
# Kolumna 58: St fra
# Kolumna 59: /
# Kolumna 60: nan
# Kolumna 61: /
# Kolumna 62: /
# Kolumna 63: nan
# Kolumna 64: /
# Kolumna 65: 4
# Kolumna 66: nan
# Kolumna 67: 0.0
# Kolumna 68: nan
# Kolumna 69: 0.0
# Kolumna 70: 8.0
# Kolumna 71: 0.0
# Kolumna 72: nan
# Kolumna 73: 0
# Kolumna 74: 9.0
# Kolumna 75: nan
# Kolumna 76: nan
# Kolumna 77: 1.4
# Kolumna 78: nan
# Kolumna 79: 0.0
# Kolumna 80: 8.0
# Kolumna 81: 0.0
# Kolumna 82: 8.0
# Kolumna 83: 0.0
# Kolumna 84: 8.0
# Kolumna 85: 0.0
# Kolumna 86: 8.0
# Kolumna 87: 0.0
# Kolumna 88: 8.0
# Kolumna 89: 0.0
# Kolumna 90: 8.0
# Kolumna 91: 0.0
# Kolumna 92: 8.0
# Kolumna 93: 0.0
# Kolumna 94: 8.0
# Kolumna 95: 0
# Kolumna 96: 8.0
# Kolumna 97: 0
# Kolumna 98: 8.0
# Kolumna 99: 0
# Kolumna 100: 8.0
# Kolumna 101: nan
# Kolumna 102: nan
# Kolumna 103: 0
# Kolumna 104: 8.0
# Kolumna 105: 0
# Kolumna 106: 8.0
#
# Sprawdzanie konkretnych kolumn:
# Wilgotność względna (kolumna 38): 0    100
# 1     99
# 2    100
# 3    100
# 4    100
# Name: 37, dtype: int64
# Suma opadów (kolumna 47): 0   -0.7
# 1   -0.3
# 2    0.4
# 3    0.5
# 4    0.4
# Name: 46, dtype: float64
#
# Po przetworzeniu - pierwsze wiersze:
#   data_pomiaru godzina_pomiaru  temperatura  predkosc_wiatru  kierunek_wiatru  \
# 0   2021-01-01              00         -0.6                2               94
# 1   2021-01-01              01         -1.9                1              162
# 2   2021-01-01              02         -1.6                2              228
# 3   2021-01-01              03         -1.6                2              226
# 4   2021-01-01              04         -1.6                2              248
#
#    wilgotnosc_wzgledna  suma_opadu  cisnienie
# 0                  100         0.0      960.3
# 1                   99         0.0      960.5
# 2                  100         0.4      960.9
# 3                  100         0.5      960.8
# 4                  100         0.4      960.9
#
# Brakujące wartości po przetworzeniu:
# data_pomiaru           0
# godzina_pomiaru        0
# temperatura            0
# predkosc_wiatru        0
# kierunek_wiatru        0
# wilgotnosc_wzgledna    0
# suma_opadu             0
# cisnienie              0
# dtype: int64
#
# Pobieranie danych za rok 2022
# Pobieranie danych z: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/terminowe/synop/2022/2022_600_s.zip
# Zapisano plik ZIP: dane/2022_600_s.zip
# Pliki w archiwum:
# - s_t_600_2022.csv
#
# Pierwszy wiersz surowych danych:
# Kolumna 0: 349190600
# Kolumna 1: BIELSKO-BIAŁA
# Kolumna 2: 2022
# Kolumna 3: 1
# Kolumna 4: 1
# Kolumna 5: 0
# Kolumna 6: 5
# Kolumna 7: nan
# Kolumna 8: 780
# Kolumna 9: nan
# Kolumna 10: 0
# Kolumna 11: 8.0
# Kolumna 12: nan
# Kolumna 13: nan
# Kolumna 14: nan
# Kolumna 15: 7
# Kolumna 16: nan
# Kolumna 17: 13335
# Kolumna 18: nan
# Kolumna 19: 13335
# Kolumna 20: nan
# Kolumna 21: 0
# Kolumna 22: 8.0
# Kolumna 23: 242
# Kolumna 24: nan
# Kolumna 25: 8
# Kolumna 26: nan
# Kolumna 27: 0
# Kolumna 28: 9.0
# Kolumna 29: 10.6
# Kolumna 30: nan
# Kolumna 31: 0.0
# Kolumna 32: 8
# Kolumna 33: U
# Kolumna 34: nan
# Kolumna 35: 10.1
# Kolumna 36: nan
# Kolumna 37: 79
# Kolumna 38: nan
# Kolumna 39: 7.1
# Kolumna 40: nan
# Kolumna 41: 969.4
# Kolumna 42: nan
# Kolumna 43: 1017.2
# Kolumna 44: nan
# Kolumna 45: 5
# Kolumna 46: -0.1
# Kolumna 47: nan
# Kolumna 48: 0.1
# Kolumna 49: nan
# Kolumna 50: 0
# Kolumna 51: 8.0
# Kolumna 52: 81
# Kolumna 53: nan
# Kolumna 54: nan
# Kolumna 55: nan
# Kolumna 56: nan
# Kolumna 57: 8.0
# Kolumna 58: nan
# Kolumna 59: nan
# Kolumna 60: 8.0
# Kolumna 61: nan
# Kolumna 62: nan
# Kolumna 63: 8.0
# Kolumna 64: nan
# Kolumna 65: 0
# Kolumna 66: 8.0
# Kolumna 67: 2.7
# Kolumna 68: nan
# Kolumna 69: 0.0
# Kolumna 70: 8.0
# Kolumna 71: nan
# Kolumna 72: 8.0
# Kolumna 73: 16
# Kolumna 74: nan
# Kolumna 75: 19.0
# Kolumna 76: 39.0
# Kolumna 77: 7.7
# Kolumna 78: nan
# Kolumna 79: 6.7
# Kolumna 80: nan
# Kolumna 81: 5.5
# Kolumna 82: nan
# Kolumna 83: 3.7
# Kolumna 84: nan
# Kolumna 85: 5.0
# Kolumna 86: nan
# Kolumna 87: 0.0
# Kolumna 88: 8.0
# Kolumna 89: 0.0
# Kolumna 90: 8.0
# Kolumna 91: 0.0
# Kolumna 92: 8.0
# Kolumna 93: 0.0
# Kolumna 94: 8.0
# Kolumna 95: 0
# Kolumna 96: 8.0
# Kolumna 97: 0
# Kolumna 98: 8.0
# Kolumna 99: 0
# Kolumna 100: 8.0
# Kolumna 101: nan
# Kolumna 102: nan
# Kolumna 103: 0
# Kolumna 104: 8.0
# Kolumna 105: 0
# Kolumna 106: 8.0
#
# Sprawdzanie konkretnych kolumn:
# Wilgotność względna (kolumna 38): 0    79
# 1    93
# 2    96
# 3    98
# 4    97
# Name: 37, dtype: int64
# Suma opadów (kolumna 47): 0   -0.1
# 1    0.5
# 2    1.3
# 3    1.9
# 4    1.9
# Name: 46, dtype: float64
#
# Po przetworzeniu - pierwsze wiersze:
#   data_pomiaru godzina_pomiaru  temperatura  predkosc_wiatru  kierunek_wiatru  \
# 0   2022-01-01              00         10.6                8              242
# 1   2022-01-01              01          9.2                7              243
# 2   2022-01-01              02          8.9                7              243
# 3   2022-01-01              03          9.0                6              251
# 4   2022-01-01              04          9.0                7              243
#
#    wilgotnosc_wzgledna  suma_opadu  cisnienie
# 0                   79         0.0      969.4
# 1                   93         0.5      969.8
# 2                   96         1.3      970.6
# 3                   98         1.9      971.3
# 4                   97         1.9      971.7
#
# Brakujące wartości po przetworzeniu:
# data_pomiaru           0
# godzina_pomiaru        0
# temperatura            0
# predkosc_wiatru        0
# kierunek_wiatru        0
# wilgotnosc_wzgledna    0
# suma_opadu             0
# cisnienie              0
# dtype: int64
#
# Pobieranie danych za rok 2023
# Pobieranie danych z: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/terminowe/synop/2023/2023_600_s.zip
# Zapisano plik ZIP: dane/2023_600_s.zip
# Pliki w archiwum:
# - s_t_600_2023.csv
#
# Pierwszy wiersz surowych danych:
# Kolumna 0: 349190600
# Kolumna 1: BIELSKO-BIAŁA
# Kolumna 2: 2023
# Kolumna 3: 1
# Kolumna 4: 1
# Kolumna 5: 0
# Kolumna 6: nan
# Kolumna 7: 8.0
# Kolumna 8: 0
# Kolumna 9: 8.0
# Kolumna 10: 0
# Kolumna 11: 8.0
# Kolumna 12: nan
# Kolumna 13: nan
# Kolumna 14: nan
# Kolumna 15: 9
# Kolumna 16: nan
# Kolumna 17: 50000
# Kolumna 18: nan
# Kolumna 19: 50000
# Kolumna 20: nan
# Kolumna 21: 0
# Kolumna 22: 8.0
# Kolumna 23: 192
# Kolumna 24: nan
# Kolumna 25: 9
# Kolumna 26: nan
# Kolumna 27: 0
# Kolumna 28: 9.0
# Kolumna 29: 15.1
# Kolumna 30: nan
# Kolumna 31: 0.0
# Kolumna 32: 8
# Kolumna 33: U
# Kolumna 34: nan
# Kolumna 35: 8.7
# Kolumna 36: nan
# Kolumna 37: 51
# Kolumna 38: nan
# Kolumna 39: 5.0
# Kolumna 40: nan
# Kolumna 41: 972.7
# Kolumna 42: nan
# Kolumna 43: 1019.9
# Kolumna 44: nan
# Kolumna 45: 7
# Kolumna 46: -0.4
# Kolumna 47: nan
# Kolumna 48: 0.0
# Kolumna 49: 9.0
# Kolumna 50: 0
# Kolumna 51: 8.0
# Kolumna 52: 0
# Kolumna 53: nan
# Kolumna 54: nan
# Kolumna 55: nan
# Kolumna 56: nan
# Kolumna 57: 8.0
# Kolumna 58: nan
# Kolumna 59: nan
# Kolumna 60: 8.0
# Kolumna 61: nan
# Kolumna 62: nan
# Kolumna 63: 8.0
# Kolumna 64: nan
# Kolumna 65: 0
# Kolumna 66: 8.0
# Kolumna 67: 8.4
# Kolumna 68: nan
# Kolumna 69: 0.0
# Kolumna 70: 8.0
# Kolumna 71: nan
# Kolumna 72: 8.0
# Kolumna 73: 15
# Kolumna 74: nan
# Kolumna 75: 23.0
# Kolumna 76: 13.0
# Kolumna 77: 8.1
# Kolumna 78: nan
# Kolumna 79: 6.8
# Kolumna 80: nan
# Kolumna 81: 5.8
# Kolumna 82: nan
# Kolumna 83: 4.4
# Kolumna 84: nan
# Kolumna 85: 5.4
# Kolumna 86: nan
# Kolumna 87: 0.0
# Kolumna 88: 8.0
# Kolumna 89: 0.0
# Kolumna 90: 8.0
# Kolumna 91: 0.0
# Kolumna 92: 8.0
# Kolumna 93: 0.0
# Kolumna 94: 8.0
# Kolumna 95: 0
# Kolumna 96: 8.0
# Kolumna 97: 0
# Kolumna 98: 8.0
# Kolumna 99: 0
# Kolumna 100: 8.0
# Kolumna 101: nan
# Kolumna 102: nan
# Kolumna 103: 0
# Kolumna 104: 8.0
# Kolumna 105: 0
# Kolumna 106: 8.0
#
# Sprawdzanie konkretnych kolumn:
# Wilgotność względna (kolumna 38): 0    51
# 1    51
# 2    47
# 3    44
# 4    40
# Name: 37, dtype: int64
# Suma opadów (kolumna 47): 0   -0.4
# 1    0.1
# 2    0.3
# 3    0.2
# 4    0.0
# Name: 46, dtype: float64
#
# Po przetworzeniu - pierwsze wiersze:
#   data_pomiaru godzina_pomiaru  temperatura  predkosc_wiatru  kierunek_wiatru  \
# 0   2023-01-01              00         15.1                9              192
# 1   2023-01-01              01         15.1               10              194
# 2   2023-01-01              02         15.8                8              188
# 3   2023-01-01              03         16.0                8              188
# 4   2023-01-01              04         16.7                7              188
#
#    wilgotnosc_wzgledna  suma_opadu  cisnienie
# 0                   51         0.0      972.7
# 1                   51         0.1      973.0
# 2                   47         0.3      973.2
# 3                   44         0.2      972.9
# 4                   40         0.0      973.0
#
# Brakujące wartości po przetworzeniu:
# data_pomiaru           0
# godzina_pomiaru        0
# temperatura            0
# predkosc_wiatru        0
# kierunek_wiatru        0
# wilgotnosc_wzgledna    0
# suma_opadu             0
# cisnienie              0
# dtype: int64
#
# Łączna liczba rekordów: 35064
# Zapisano połączone dane do: dane/dane_stacja_600.csv
#
# Przykładowe dane:
#   data_pomiaru godzina_pomiaru  temperatura  predkosc_wiatru  kierunek_wiatru  \
# 0   2020-01-01              00          2.8                4              251
# 1   2020-01-01              01          2.7                5              245
# 2   2020-01-01              02          2.7                4              249
# 3   2020-01-01              03          2.6                4              250
# 4   2020-01-01              04          2.4                3              275
#
#    wilgotnosc_wzgledna  suma_opadu  cisnienie
# 0                   79         0.9      982.8
# 1                   80         0.7      982.9
# 2                   81         0.3      983.0
# 3                   81         0.2      983.0
# 4                   81         0.6      983.5
#
# Kolumny w danych:
# ['data_pomiaru', 'godzina_pomiaru', 'temperatura', 'predkosc_wiatru', 'kierunek_wiatru', 'wilgotnosc_wzgledna', 'suma_opadu', 'cisnienie']
